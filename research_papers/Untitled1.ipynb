# %%
from fastai.vision.all import *

# %%
path = Path('/home/jupyter/charliemacuject/research_papers/fastai/jordanjames')
dls = ImageDataLoaders.from_folder(path, item_tfms=Resize(224))

# %%
learn = cnn_learner(dls, resnet34, metrics=accuracy, lr=10e-8)

# %%
learn.fine_tune(2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>nan</td>
#       <td>3.261352</td>
#       <td>0.600000</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>nan</td>
#       <td>3.261352</td>
#       <td>0.600000</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>nan</td>
#       <td>3.261352</td>
#       <td>0.600000</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.show_results()
