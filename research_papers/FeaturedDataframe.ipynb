# %%
import numpy as np
import pandas as pd
from scipy import stats
import seaborn as sns
from scipy.integrate import quad

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/home/jupyter/charliemacuject/research_papers/data/master_macuject.csv', low_memory=False)

# %%
max(df['ExamLeftGraph'])
# Out:
# 1.5

# %%
df.head()
# Out:
#    Patient::PatientSurname  Patient::PatientFirstname Patient::PatientBCID  \
# 0                      NaN                        NaN                 4221
# 1                      NaN                        NaN                 4221
# 2                      NaN                        NaN                 4221
# 3                      NaN                        NaN                 4221
# 4                      NaN                        NaN                 4221
#
#   Patient::PatientGender  Patient::PatientDOB  Current age in 2020  \
# 0                 Female                  NaN                  100
# 1                 Female                  NaN                  100
# 2                 Female                  NaN                  100
# 3                 Female                  NaN                  100
# 4                 Female                  NaN                  100
#
#   CreatedDate JobClinic            DoctorName  Patient::PatientHistorySum  \
# 0  24/04/2007       NaN  Dr. Devinder Chauhan                         NaN
# 1  04/05/2007       NaN  Dr. Devinder Chauhan                         NaN
# 2  01/06/2007       NaN  Dr. Devinder Chauhan                         NaN
# 3  20/07/2007       NaN  Dr. Devinder Chauhan                         NaN
# 4  17/08/2007       NaN  Dr. Devinder Chauhan                         NaN
#
#    ... InjectionRightType InjectionLeftType InjectionRightTypeNextTime  \
# 0  ...                NaN               NaN                        NaN
# 1  ...                NaN          Lucentis                        NaN
# 2  ...                NaN          Lucentis                        NaN
# 3  ...                NaN          Lucentis                        NaN
# 4  ...                NaN               NaN                        NaN
#
#   InjectionNextTimeRight InjectionLeftTypeNextTime InjectionNextTimeLeft  \
# 0                    NaN                       NaN                   NaN
# 1                    NaN                  Lucentis                   NaN
# 2                    NaN                  Lucentis                   NaN
# 3                    NaN                  Lucentis                   NaN
# 4                    NaN                       NaN                   NaN
#
#    InjectionAdministeredRight  InjectionAdministeredLeft  BC_RightInjEF  \
# 0                         NaN                        NaN            NaN
# 1                         NaN                        NaN            NaN
# 2                         NaN                        NaN            NaN
# 3                         NaN                        NaN            NaN
# 4                         NaN                        NaN            NaN
#
#    BC_LEFTInjEF
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#
# [5 rows x 40 columns]

# %%
def drop_less(tdf):
    count_left = tdf["InjectionNextTimeLeft"].isna().sum()
    count_right = tdf["InjectionNextTimeRight"].isna().sum()
    if count_left > count_right:
        tdf = tdf.drop(columns=['ExamLeftGraph', 'InjectionLeftType', 'InjectionNextTimeLeft'])
        tdf = tdf.rename(columns={"ExamRightGraph": "ExamGraph", "InjectionRightType":"InjectionType", "InjectionNextTimeRight":"NextTime"})
    elif count_left < count_right:
        tdf = tdf.drop(columns=['ExamRightGraph', 'InjectionRightType', 'InjectionNextTimeRight'])
        tdf = tdf.rename(columns={"ExamLeftGraph": "ExamGraph", "InjectionLeftType":"InjectionType", "InjectionNextTimeLeft":"NextTime"})
    else:
        tdf = tdf.drop(columns=['ExamRightGraph', 'InjectionRightType', 'InjectionNextTimeRight'])
        tdf = tdf.rename(columns={"ExamLeftGraph": "ExamGraph", "InjectionLeftType":"InjectionType", "InjectionNextTimeLeft":"NextTime"})
    tdf['ExamGraph'] = np.where(tdf['ExamGraph'] > 1.0, 1.0, tdf['ExamGraph'])
    return tdf

# function to get days since first and append it as a column
def days_since_first(df):
    df['CreatedDate'] = pd.to_datetime(df['CreatedDate'], dayfirst=True)
    days_list = [0]
    date0 = df['CreatedDate'].iloc[0]
    for i in range(1, len(df)):
        date1 = df['CreatedDate'].iloc[i]
        diff = date1 - date0
        diff = diff.days
        days_list.append(diff)
    df['DaysFirst'] = days_list
    return df

# function to get actual time between injections
def days_between(df):
    df['CreatedDate'] = pd.to_datetime(df['CreatedDate'], dayfirst=True)
    df.sort_values(by=['CreatedDate'], inplace=True)
    time_list = ["NaN"]
    for i in range(len(df)-1):
        date0 = df['CreatedDate'].iloc[i]
        date1 = df['CreatedDate'].iloc[i+1]
        diff = date1 - date0
        diff = round(diff.days / 7, 2)
        time_list.append(diff)
    df['actual_time'] = time_list
    return df

# function to get the adherence factor for any specific visit
def adherence_factor(df):
    adherence_list = ["NaN"]
    for i in range(len(df)-1):
        rec = df['NextTime'].iloc[i]
        actual = df['actual_time'].iloc[i+1]
        adherence = round(actual / rec, 2)
        adherence_list.append(adherence)
    df['adherence_factor'] = adherence_list
    return df

# function to find the running mean adherence over all previous appointments
def running_adherence(df):
    running_list = []
    for i in range(len(df)):
        mean_list = df['adherence_factor'].iloc[0:i].dropna().tolist()
        try:
            mean_list.remove("NaN")
        except:
            pass
        try:
            total = sum(mean_list)
            length = len(mean_list)
            mean = round(total / length, 2)
            running_list.append(mean)
        except:
            running_list.append("NaN")
            i += 1
    df['running_ad'] = running_list
    return df

# function to find the running standard deviation over all previous appointments
def std_dev(df):
    dev_list = []
    for i in range(len(df)):
        std_list = df['adherence_factor'].iloc[0:i].dropna().tolist()
        try:
            std_list.remove("NaN")
        except:
            pass
        try:
            dev_list.append(round(np.std(std_list), 4))
        except:
            latest = dev_list[-1]
            dev_list.append(latest)
            i += 1
    df['st_dev'] = dev_list
    return df

# function to get average adherence over last five visits
def ad_five(df):
    running_list = []
    for i in range(len(df)):
        if i < 4:
            mean_list = df['adherence_factor'].iloc[0:i].dropna().tolist()
        else:
            mean_list = df['adherence_factor'].iloc[(i-5):i].dropna().tolist()
        try:
            mean_list.remove("NaN")
        except:
            pass
        try:
            total = sum(mean_list)
            length = len(mean_list)
            mean = round(total / length, 2)
            running_list.append(mean)
        except:
            running_list.append("NaN")
            i += 1
    df['ad_five'] = running_list
    return df

# function to get previous vision score
def prev_vision(df):
    vision_list = []
    for i in range(len(df)):
        if i == 0:
            vision_list.append(df['ExamGraph'].iloc[i])
        else:
            vision_list.append(df['ExamGraph'].iloc[i-1])
    df['prev_vision'] = vision_list
    return df

# function to get average vision score
def mean_vision(df):
    running_list = []
    for i in range(len(df)):
        mean_list = df['ExamGraph'].iloc[0:i].dropna().tolist()
        try:
            mean_list.remove("NaN")
        except:
            pass
        try:
            total = sum(mean_list)
            length = len(mean_list)
            mean = round(total / length, 2)
            running_list.append(mean)
        except:
            running_list.append("NaN")
            i += 1
    df['mean_vision'] = running_list
    return df

# function to get average vision from last five visits
def last_five(df):
    running_list = []
    for i in range(len(df)):
        if i < 4:
            mean_list = df['ExamGraph'].iloc[0:i].dropna().tolist()
        else:
            mean_list = df['ExamGraph'].iloc[(i-5):i].dropna().tolist()
        try:
            mean_list.remove("NaN")
        except:
            pass
        try:
            total = sum(mean_list)
            length = len(mean_list)
            mean = round(total / length, 2)
            running_list.append(mean)
        except:
            running_list.append("NaN")
            i += 1
    df['last_five'] = running_list
    return df

# function to get average vision from last 10 visits
def last_ten(df):
    running_list = []
    for i in range(len(df)):
        if i < 9:
            mean_list = df['ExamGraph'].iloc[0:i].dropna().tolist()
        else:
            mean_list = df['ExamGraph'].iloc[(i-10):i].dropna().tolist()
        try:
            mean_list.remove("NaN")
        except:
            pass
        try:
            total = sum(mean_list)
            length = len(mean_list)
            mean = round(total / length, 2)
            running_list.append(mean)
        except:
            running_list.append("NaN")
            i += 1
    df['last_ten'] = running_list
    return df

# function to get average vision from last 3 visits
def last_three(df):
    running_list = []
    for i in range(len(df)):
        if i < 2:
            mean_list = df['ExamGraph'].iloc[0:i].dropna().tolist()
        else:
            mean_list = df['ExamGraph'].iloc[(i-3):i].dropna().tolist()
        try:
            mean_list.remove("NaN")
        except:
            pass
        try:
            total = sum(mean_list)
            length = len(mean_list)
            mean = round(total / length, 2)
            running_list.append(mean)
        except:
            running_list.append("NaN")
            i += 1
    df['last_three'] = running_list
    return df

# function to find the running standard deviation over all previous appointments
def std_vision(df):
    dev_list = []
    for i in range(len(df)):
        std_list = df['ExamGraph'].iloc[0:i].dropna().tolist()
        try:
            std_list.remove("NaN")
        except:
            pass
        try:
            dev_list.append(round(np.std(std_list), 4))
        except:
            latest = dev_list[-1]
            dev_list.append(latest)
            i += 1
    df['std_vision'] = dev_list
    return df

# function to get average vision from last five visits
def std_five(df):
    running_list = []
    for i in range(len(df)):
        if i < 4:
            mean_list = df['ExamGraph'].iloc[0:i].dropna().tolist()
        else:
            mean_list = df['ExamGraph'].iloc[(i-5):i].dropna().tolist()
        try:
            mean_list.remove("NaN")
        except:
            pass
        try:
            running_list.append(round(np.std(mean_list), 4))
        except:
            running_list.append("NaN")
            i += 1
    df['std_five'] = running_list
    return df

# function to only keep patients if they started after 2016
def patient_clean(df):
    items = pd.to_datetime(df['CreatedDate'])
    cutoff = pd.to_datetime("2016-01-01")
    return all(visit > cutoff for visit in items)

# function to filter dataframe based on cutoff
def cutoff_filter():
    df = pd.read_csv('/home/jupyter/charliemacuject/research_papers/data/master_macuject.csv')
    df = df.rename(columns={"Patient::PatientBCID": "ID", "Patient::PatientGender": "gender", "Current age in 2020": "age"})
    id_list = df["ID"].unique()
    frames = []
    for i in range(len(id_list)):
        pdf = df[df["ID"] == id_list[i]]
        if patient_clean(pdf) == True:
            frames.append(pdf)
        else:
            i += 1
    master = pd.concat(frames)
    return master

# %%
master = cutoff_filter()
master.head()
# Out:
#      Patient::PatientSurname  Patient::PatientFirstname    ID gender  \
# 115                      NaN                        NaN  4222   Male
# 116                      NaN                        NaN  4222   Male
# 117                      NaN                        NaN  4222   Male
# 118                      NaN                        NaN  4222   Male
# 119                      NaN                        NaN  4222   Male
#
#      Patient::PatientDOB  age CreatedDate JobClinic            DoctorName  \
# 115                  NaN   91  25/01/2017  Box Hill  Dr. Devinder Chauhan
# 116                  NaN   91  21/02/2017  Box Hill  Dr. Devinder Chauhan
# 117                  NaN   91  28/03/2017  Box Hill  Dr. Devinder Chauhan
# 118                  NaN   91  09/05/2017  Box Hill  Dr. Devinder Chauhan
# 119                  NaN   91  08/08/2017  Box Hill  Dr. Devinder Chauhan
#
#      Patient::PatientHistorySum  ... InjectionRightType InjectionLeftType  \
# 115                         NaN  ...                NaN               NaN
# 116                         NaN  ...           Lucentis               NaN
# 117                         NaN  ...           Lucentis               NaN
# 118                         NaN  ...           Lucentis               NaN
# 119                         NaN  ...           Lucentis               NaN
#
#     InjectionRightTypeNextTime InjectionNextTimeRight  \
# 115                        NaN                    NaN
# 116                   Lucentis                    4.0
# 117                   Lucentis                    6.0
# 118                   Lucentis                    8.0
# 119                   Lucentis                   12.0
#
#     InjectionLeftTypeNextTime InjectionNextTimeLeft  \
# 115                       NaN                   NaN
# 116                       NaN                   NaN
# 117                       NaN                   NaN
# 118                       NaN                   NaN
# 119                       NaN                   NaN
#
#      InjectionAdministeredRight  InjectionAdministeredLeft  BC_RightInjEF  \
# 115                         NaN                        NaN       LUCENTIS
# 116                         Yes                        NaN       LUCENTIS
# 117                         Yes                        NaN       LUCENTIS
# 118                         Yes                        NaN       LUCENTIS
# 119                         Yes                        NaN       LUCENTIS
#
#      BC_LEFTInjEF
# 115           NaN
# 116           NaN
# 117           NaN
# 118           NaN
# 119           NaN
#
# [5 rows x 40 columns]

# %%
len(df), len(master)
# Out:
# (56641, 11081)

# %%
master = cutoff_filter()

# get patient IDs
id_list = master["ID"].unique()
id_list

def dataframe_gen(pat_id):
    df = master
    df = df[df["ID"] == pat_id]
    df = drop_less(df)
    df = days_since_first(df)
    df = days_between(df)
    df = adherence_factor(df)
    df = running_adherence(df)
    df = std_dev(df)
    df = prev_vision(df)
    df = mean_vision(df)
    df = std_vision(df)
    return df

# %%
df1 = dataframe_gen(id_list[0])
df2 = dataframe_gen(id_list[1])
frames = [df1, df2]
result = pd.concat(frames)
result
# Out:
#      Patient::PatientSurname  Patient::PatientFirstname     ID  gender  \
# 115                      NaN                        NaN   4222    Male
# 116                      NaN                        NaN   4222    Male
# 117                      NaN                        NaN   4222    Male
# 118                      NaN                        NaN   4222    Male
# 119                      NaN                        NaN   4222    Male
# 120                      NaN                        NaN   4222    Male
# 121                      NaN                        NaN   4222    Male
# 122                      NaN                        NaN   4222    Male
# 123                      NaN                        NaN   4222    Male
# 124                      NaN                        NaN   4222    Male
# 576                      NaN                        NaN  19799  Female
# 577                      NaN                        NaN  19799  Female
#
#      Patient::PatientDOB  age CreatedDate JobClinic  \
# 115                  NaN   91  2017-01-25  Box Hill
# 116                  NaN   91  2017-02-21  Box Hill
# 117                  NaN   91  2017-03-28  Box Hill
# 118                  NaN   91  2017-05-09  Box Hill
# 119                  NaN   91  2017-08-08  Box Hill
# 120                  NaN   91  2017-10-31  Box Hill
# 121                  NaN   91  2018-01-23  Box Hill
# 122                  NaN   91  2018-04-24  Box Hill
# 123                  NaN   91  2018-07-24  Box Hill
# 124                  NaN   91  2018-11-13  Box Hill
# 576                  NaN   70  2017-01-06  Box Hill
# 577                  NaN   70  2017-01-06  Box Hill
#
#                      DoctorName  Patient::PatientHistorySum  ...  \
# 115        Dr. Devinder Chauhan                         NaN  ...
# 116        Dr. Devinder Chauhan                         NaN  ...
# 117        Dr. Devinder Chauhan                         NaN  ...
# 118        Dr. Devinder Chauhan                         NaN  ...
# 119        Dr. Devinder Chauhan                         NaN  ...
# 120        Dr. Devinder Chauhan                         NaN  ...
# 121        Dr. Devinder Chauhan                         NaN  ...
# 122        Dr. Devinder Chauhan                         NaN  ...
# 123  Dr. Devinder Chauhan (BOR)                         NaN  ...
# 124  Dr. Devinder Chauhan (BOR)                         NaN  ...
# 576              Dr. Eric Mayer                         NaN  ...
# 577              Dr. Eric Mayer                         NaN  ...
#
#     BC_RightInjEF BC_LEFTInjEF DaysFirst actual_time adherence_factor  \
# 115      LUCENTIS          NaN         0         NaN              NaN
# 116      LUCENTIS          NaN        27        3.86              NaN
# 117      LUCENTIS          NaN        62         5.0             1.25
# 118      LUCENTIS          NaN       104         6.0              1.0
# 119      LUCENTIS          NaN       195        13.0             1.62
# 120      LUCENTIS          NaN       279        12.0              1.0
# 121      LUCENTIS          NaN       363        12.0              1.0
# 122      LUCENTIS          NaN       454        13.0             1.08
# 123      LUCENTIS          NaN       545        13.0             1.08
# 124      LUCENTIS          NaN       657        16.0             1.33
# 576           NaN          NaN         0         NaN              NaN
# 577           NaN          NaN         0         0.0              NaN
#
#     running_ad  st_dev  prev_vision  mean_vision  std_vision
# 115        NaN     NaN     0.166667          NaN         NaN
# 116        NaN     NaN     0.166667         0.17      0.0000
# 117        NaN     NaN     0.400000         0.28      0.1167
# 118       1.25  0.0000     0.333333          0.3      0.0981
# 119       1.12  0.1250     0.333333         0.31      0.0862
# 120       1.29  0.2547     0.333333         0.31      0.0777
# 121       1.22  0.2538     0.333333         0.32      0.0714
# 122       1.17  0.2431     0.333333         0.32      0.0663
# 123       1.16  0.2247     0.333333         0.32      0.0622
# 124       1.15  0.2098     0.250000         0.31      0.0627
# 576        NaN     NaN     0.666667          NaN         NaN
# 577        NaN     NaN     0.666667         0.67      0.0000
#
# [12 rows x 45 columns]

# %%
def master_dataframe():
    df = cutoff_filter()
    # get patient IDs
    id_list = df["ID"].unique()
    frames = []
    for i in range(len(id_list)):
        try:
            pdf = dataframe_gen(id_list[i])
            pdf = pdf.drop(columns=['ID'])
            pdf['ID'] = i
            frames.append(pdf)
        except:
            i += 1
    master = pd.concat(frames)
    return master

master = master_dataframe()
len(master)
# Out:
# 11081

# %%
master.columns
# Out:
# Index(['Patient::PatientSurname', 'Patient::PatientFirstname', 'gender',
#        'Patient::PatientDOB', 'age', 'CreatedDate', 'JobClinic', 'DoctorName',
#        'Patient::PatientHistorySum', 'Patient::DiagRightCalc',
#        'Patient::DiagLeftCalc', 'InjectionPhaseRight', 'InjectionPhaseLeft',
#        'InjectionRightSymptom', 'InjectionLeftSymptom', 'ExamRightUaCalc',
#        'ExamRightGlCalc', 'ExamRightPhCalc', 'ExamRightIop', 'ExamGraph',
#        'ExamLeftUaCalc', 'ExamLeftGlCalc', 'ExamLeftPhCalc', 'ExamLeftIop',
#        'InjectionRightFindingsCalc', 'InjectionLeftFindingsCalc',
#        'InjectionRightMacFindingHaem', 'InjectionLeftMacFindingHaem',
#        'InjectionType', 'InjectionRightTypeNextTime', 'NextTime',
#        'InjectionLeftTypeNextTime', 'InjectionAdministeredRight',
#        'InjectionAdministeredLeft', 'BC_RightInjEF', 'BC_LEFTInjEF',
#        'DaysFirst', 'actual_time', 'adherence_factor', 'running_ad', 'st_dev',
#        'prev_vision', 'mean_vision', 'std_vision', 'ID'],
#       dtype='object')

# %%
master.drop(columns=['Patient::PatientSurname', 'Patient::PatientFirstname',
       'Patient::PatientDOB', 'JobClinic', 'DoctorName',
       'Patient::PatientHistorySum', 'Patient::DiagRightCalc',
       'Patient::DiagLeftCalc', 'InjectionPhaseRight', 'InjectionPhaseLeft',
       'InjectionRightSymptom', 'InjectionLeftSymptom', 'ExamRightUaCalc',
       'ExamRightGlCalc', 'ExamRightPhCalc', 'ExamRightIop',
       'ExamLeftUaCalc', 'ExamLeftGlCalc', 'ExamLeftPhCalc', 'ExamLeftIop',
       'InjectionRightFindingsCalc', 'InjectionLeftFindingsCalc',
       'InjectionRightMacFindingHaem', 'InjectionLeftMacFindingHaem',
       'InjectionRightTypeNextTime',
       'InjectionLeftTypeNextTime', 'InjectionAdministeredRight',
       'InjectionAdministeredLeft', 'BC_RightInjEF', 'BC_LEFTInjEF'], inplace=True)

# %%
master.dropna(inplace=True)

# %%
master
# Out:
#        gender  age CreatedDate  ExamGraph InjectionType  NextTime  DaysFirst  \
# 118      Male   91  2017-05-09   0.333333      Lucentis       8.0        104
# 119      Male   91  2017-08-08   0.333333      Lucentis      12.0        195
# 120      Male   91  2017-10-31   0.333333      Lucentis      12.0        279
# 121      Male   91  2018-01-23   0.333333      Lucentis      12.0        363
# 122      Male   91  2018-04-24   0.333333      Lucentis      12.0        454
# ...       ...  ...         ...        ...           ...       ...        ...
# 56399  Female   96  2017-06-13   0.200000         Eylea       8.0        102
# 56484  Female   57  2020-01-07   0.333333      Lucentis       4.0        203
# 56485  Female   57  2020-02-13   0.333333      Lucentis       6.0        240
# 56488  Female   57  2020-06-16   0.500000      Lucentis       8.0        364
# 56489  Female   57  2020-08-12   0.666667      Lucentis      10.0        421
#
#       actual_time adherence_factor running_ad  st_dev  prev_vision  \
# 118           6.0              1.0       1.25  0.0000     0.333333
# 119          13.0             1.62       1.12  0.1250     0.333333
# 120          12.0              1.0       1.29  0.2547     0.333333
# 121          12.0              1.0       1.22  0.2538     0.333333
# 122          13.0             1.08       1.17  0.2431     0.333333
# ...           ...              ...        ...     ...          ...
# 56399         6.0              1.0       1.07  0.1800     0.200000
# 56484         4.0              1.0        1.0  0.0700     0.333333
# 56485        5.29             1.32        1.0  0.0572     0.333333
# 56488         6.0              1.0       1.05  0.1415     0.500000
# 56489        8.14             1.02       1.05  0.1307     0.500000
#
#       mean_vision  std_vision   ID
# 118           0.3      0.0981    0
# 119          0.31      0.0862    0
# 120          0.31      0.0777    0
# 121          0.32      0.0714    0
# 122          0.32      0.0663    0
# ...           ...         ...  ...
# 56399        0.19      0.0157  506
# 56484        0.38      0.0601  507
# 56485        0.38      0.0583  507
# 56488         0.4      0.0722  507
# 56489        0.41      0.0750  507
#
# [6540 rows x 15 columns]

# %%
max(master['ExamGraph'])
# Out:
# 1.0

# %%
master.to_csv('/home/jupyter/charliemacuject/research_papers/data/master_allstats.csv')
